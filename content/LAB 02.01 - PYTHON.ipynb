# %% [markdown]
# # LAB 02.01 - Python
#
# <a target="_blank" href="https://colab.research.google.com/github/rramosp/ai4eng.v1/blob/main/content/LAB%2002.01%20-%20PYTHON.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget --no-cache -O init.py -q https://raw.githubusercontent.com/rramosp/ai4eng.v1/main/content/init.py
import init; init.init(force_download=False); init.get_weblink()
# Out:
# <meta name="google-signin-client_id"
#       content="461673936472-kdjosv61up3ac1ajeuq6qqu72upilmls.apps.googleusercontent.com"/>
# <script src="https://apis.google.com/js/client:platform.js?onload=google_button_start"></script>
# replicating local resources
# <h3>See <a href='https://m5knaekxo6.execute-api.us-west-2.amazonaws.com/dev-v0001/rlxmooc/web/login' target='_blank'>my courses and progress</a></h2>

# %%
from local.lib.rlxmoocapi import submit, session
session.LoginSequence(endpoint=init.endpoint, course_id=init.course_id, lab_id="L02.01", varname="student");
# Out:
# logging in as paula.guaring@udea.edu.co... please wait
#
# -------------
# using course session ai4eng.v1.udea.r4::2026.1
# success!! you are logged in
# -------------

# %%
import numpy as np

# %% [markdown]
# ## Task 1: Palindrome
#
# Determine whether an integer number $n$ is a palindrome, this is, if it is the same number when read left to right and when read right to left. Return `True` if so, otherwise return `False`.
#
# **Execution example**
#
# ```python
# >>> palindromo(n=3456543)
# True
#
# >>> palindromo(n=543)
# False
# ```
#
# **hint**: transform it into string, reverse it and check equality
#
# **challenge**: use one single line of code

# %%
def palindromo(n): # assume n is an integer

    # your code here
    r = str(n) == str(n)[::-1]
    return r # r must be boolean True/False

# %% [markdown]
# check your code manually

# %%
print (palindromo(12321))
print (palindromo(12322))
# Out:
# True
# False

# %% [markdown]
# **submit your code**

# %%
student.submit_task(globals(), task_id="task_01");
# Out:
#                     <b>task_01 submitted.</b> <b><font color="blue">your grade is 5</font></b>
#                     <p/><pre>----- grader message -------</pre>testing with 100 random calls<br/><b>correct</b><pre>----------------------------</pre>
#                     <p/><p/>
#                     <div style="font-size:10px"><b>SUBMISSION CODE</b> jdkwwhQBYBSYPuMH+3i7bHzlf1EHyu/Dhz82La0NsdsnPAjWAZCc2DntUe0dV+HpTWWXkQfy1Bb2mu5AJKC9CUUSRPNRk9CYpXYUU/0w9iMwuFnl7SFV1LtNHiG9yyG+xsVDCuffzg8mraR0CVmt72Osf+MbVvmJrcKvV7m/4pY=</div>

# %% [markdown]
# ## Task 2: Money Change
#
# En este ejercicio, su programa recibirá un monto entre 1 y 99 centavos de Dolar, Escriba un metodo que retorne en una lista, cuantas monedas son necesarias para devolverle a alguien dicho valor, si únicamente se cuenta con monedas de 1, 10 y 25 centavos. La lista debe entregarse de la siguiente manera:
#
# In this task your function will receive an amount between 1 and 99 cents and will have to return a list with three numbers [$n_1$, $n_{10}$, $n_{25}$], specifying how many coins of 1, 10 and 25 cents are required to obtain the given amonut. We only have coints of 1, 10 and 25 cents. There are no other kinds of coins.
#
# If the amount given is less than 1 or more than 99 you must return `None`.
#
# **Execution example**
#
# ```python
# >>> change_money(n=55)
# [5,0,2]
#
# >>> change_money(n=200)
# None
#
# >>> change_money(n=47)
# [2,2,1]
# ```
#
# **hint**: use `\\` for integer division

# %%
def change_money(n):
    r=[0,0,0] #recall: r[0]== n_1, r[1]== n_10 y r[2]== n_25
    if n>99 or n<1:
       return None
    r[2] = n // 25
    n = n % 25
    r[1] = n // 10
    n = n % 10
    r[0] = n

    return r

    ## tu codigo aquí

# %% [markdown]
# **submit your code**

# %%
student.submit_task(globals(), task_id="task_02");
# Out:
#                     <b>task_02 submitted.</b> <b><font color="blue">your grade is 5</font></b>
#                     <p/><pre>----- grader message -------</pre>testing with 100 random calls<br/><b>correct</b><pre>----------------------------</pre>
#                     <p/><p/>
#                     <div style="font-size:10px"><b>SUBMISSION CODE</b> yH+2zVzsZ2RtYEMUG0fawCwYdVndgbIJH2Ozd91QfKnYoQRDHVKIyFJ3G+Pt2lU1X6IidFd3iETXU0gWtULbykN2zCyeRJC74WEoN3RbPSpnN68MCwnVqNIjzxH53cXwPLpQ/igJ+myEVSDMdVRqBlfsjuuGFvL6cGJKm5As/Q8=</div>

# %% [markdown]
# ## Task 3: Fibonacci
#
# Complete the function below so that given an integer $n$ it computes the $n^{th}$ term of the Fibonacci series:
#
# $$ f_n = f_{n-1}+f_{n-2}$$
#
# Where $$f_0=0 \:\:\text{ y }\:\:f_1=1 $$ so that: $$f_2=1+0=1$$ $$f_3=1+1=2$$ $$f_4=2+1=3$$ and so on
#
# ### Execution example
# ```python
#
# >>> fibonacci(10)
# 55
#
# >>> fibonacci(36)
# 14930352
# ```

# %%
def fibonacci(n):
    f_1=1
    f_2=1
    suma=0

    if n == 0: return 0
    if n == 1: return 1

    for i in range(2, n+1):
      suma = f_1 + f_2
      f_2 = f_1
      f_1 = suma

    return suma

# %% [markdown]
# **check manually your code**

# %%
fibonacci(10), fibonacci(36)
# Out:
# (89, 24157817)

# %% [markdown]
# **submit your code**

# %%
student.submit_task(globals(), task_id="task_03");
# Out:
#                     <b>task_03 submitted.</b> <b><font color="blue">your grade is 0</font></b>
#                     <p/><pre>----- grader message -------</pre><b>incorrect:</b> testing with 100 random calls<br/>incorrect answer. input was 11 but you returned 144, correct answer was 89<pre>----------------------------</pre>
#                     <p/><p/>
#                     <div style="font-size:10px"><b>SUBMISSION CODE</b> +LeGJhN1jhA95kYS3FhgCcjXskehMTp7enmPaXFnu5816hkJ/nYZHtQSP9IZ5KFTObT6j7IKRK1P3uPROal+bTzw9jvWr0rBtJGnQFg+AHm4nPQpAnEfd+7X6A6p1PSSkxjSLj4ObZ4AJxgRyChdVZ4jYvT2lb9xD2gLaaQla5Q=</div>

# %% [markdown]
# ## Task 4: Perfect number
#
# complete the following function so that it accepts an integer $n$ and returns `True` if $n$ is a perfect number and `False` otherwise.
#
# A perfect number is a positive integer that is equal to the sum of its positive divisors, excluding the number itself. For instance $6=3+2+1$
#
# See https://en.wikipedia.org/wiki/Perfect_number
#
# **Execution example**
# ```python
# >>> perfecto(6)
# True
#
# >>> perfecto(51)
# False
#
# >>> perfecto(496)
# True
# ```
# **hint**: make a loop of all numbers up to $n$ and use the modulus operator `%` to identify which are the divisors, then sum them up.

# %%
n = 12
n%2, n%3, n%4, n%5, n%6, n%7, n%8
# Out:
# (0, 0, 0, 2, 0, 5, 4)

# %%
def perfecto(n):
    suma = 0
    for i in range(1, n):
      if n % i == 0:
        suma += i
    return suma == n

# %% [markdown]
# **check your answer**

# %%
perfecto(6), perfecto(51), perfecto(496)
# Out:
# (True, False, True)

# %% [markdown]
# **submit your code**

# %%
student.submit_task(globals(), task_id="task_04");
# Out:
#                     <b>task_04 submitted.</b> <b><font color="blue">your grade is 5</font></b>
#                     <p/><pre>----- grader message -------</pre>testing with 100 random calls<br/><b>correct</b><pre>----------------------------</pre>
#                     <p/><p/>
#                     <div style="font-size:10px"><b>SUBMISSION CODE</b> wCByiFR2AxsV8oorfBsXrNPZDvJHGAQScXUjsHlZ+lN5etrYdPQcTwINHL4CtQdJA5QAVSM7+KnqieP1xU4gObMjZv0ywj44G4nlKOxAAQ0/gGAXKavVc9Wqlkv2M+DtBzbZpCfbBekOnWgjW/cT4O2DwubSgKx7o8U69dxr104=</div>

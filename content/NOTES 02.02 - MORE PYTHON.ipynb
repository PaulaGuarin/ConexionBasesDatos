# %% [markdown]
# # 02.02 - MORE PYTHON
#
#
# <a target="_blank" href="https://colab.research.google.com/github/rramosp/ai4eng.v1/blob/main/content/NOTES%2002.02%20-%20MORE%20PYTHON.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget --no-cache -O init.py -q https://raw.githubusercontent.com/rramosp/ai4eng.v1/main/content/init.py
import init; init.init(force_download=False); init.get_weblink()
# Out:
# <meta name="google-signin-client_id"
#       content="461673936472-kdjosv61up3ac1ajeuq6qqu72upilmls.apps.googleusercontent.com"/>
# <script src="https://apis.google.com/js/client:platform.js?onload=google_button_start"></script>
# replicating local resources
# <h3>See <a href='https://m5knaekxo6.execute-api.us-west-2.amazonaws.com/dev-v0001/rlxmooc/web/login' target='_blank'>my courses and progress</a></h2>

# %%
import numpy as np

# %% [markdown]
# ## Functions
#
# Recall that Python is an indented language. It does not uses any kind of brakets to delimit the scope of programming structures, which are signaled by **changes in indentation**
#
# Arguments types are not declared, implementation must be prepared to deal with the data types you want

# %%
def f1(a,b):
    r = a*2
    return r+b

def gt(a,b):
    if a>b:
        return a
    else:
        return b

# %%
f1(2,3)
# Out:
# 7

# %%
f1(['hola', 2], [3])
# Out:
# ['hola', 2, 'hola', 2, 3]

# %%
f1('pepe', 'gotera')
# Out:
# 'pepepepegotera'

# %%
gt(3,4)
# Out:
# 4

# %%
gt("hola","adios")
# Out:
# 'hola'

# %% [markdown]
# functions can have default values

# %%
def f_power(x, p=2):
    return x**p

f_power(3)
# Out:
# 9

# %%
f_power(3,2)
# Out:
# 9

# %% [markdown]
# args can be named when calling the function and, if so, **any order** is ok

# %%
f_power(p=2, x=3)
# Out:
# 9

# %% [markdown]
# functions can have functions defined within, but they are only visible inside the function

# %%
def f(a,b):
    def squared(x):
        return x**2
    return squared(a+b)

# %%
f(2,3)
# Out:
# 25

# %%
squared(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_308/2355033953.py in <cell line: 0>()
# ----> 1 squared(3)
#
# NameError: name 'squared' is not defined

# %% [markdown]
# functions are regular python objects which can be passed around

# %%
def apply_if_int(f, x):
    if type(x)==int:
        return f(x)

    return x

# %%
def cubed(x):
    return x**3

# %%
apply_if_int(cubed, 3)
# Out:
# 27

# %%
apply_if_int(cubed, 3.)
# Out:
# 3.0

# %% [markdown]
# `map` exploits this

# %%
map(cubed, [10,20,3,-2,9])

# %%
list(map(cubed, [10,20,3,-2,9]))
# Out:
# [1000, 8000, 27, -8, 729]

# %% [markdown]
# **lambda** functions are like constants

# %%
list(map(lambda x: x**2, [10,20,3,-2,9]))
# Out:
# [100, 400, 9, 4, 81]

# %% [markdown]
# and can even be used to define simple functions

# %%
sqrd = lambda x: x**2
sqrd(8)
# Out:
# 64

# %%
list(map(sqrd, [10,20,3,-2,9]))
# Out:
# [100, 400, 9, 4, 81]

# %% [markdown]
# ## Exceptions

# %% [markdown]
# **catching**

# %%
int(3.2)
# Out:
# 3

# %%
int("hola")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_308/754444761.py in <cell line: 0>()
# ----> 1 int("hola")
#
# ValueError: invalid literal for int() with base 10: 'hola'

# %%
def int_times_two(x):
    try:
        return(int(x)*2)
    except ValueError:
        return 0

# %%
int_times_two(2)
# Out:
# 4

# %%
int_times_two(2.5)
# Out:
# 4

# %%
int_times_two("hola")
# Out:
# 0

# %% [markdown]
# **raising**

# %%
def get_positive_integer_from_user():
    a = int(input("Enter a positive integer: "))
    if a <= 0:
        raise ValueError("That is not a positive number!")
    print ("thanks!")

# %%
get_positive_integer_from_user()
# Out:
# Enter a positive integer: 6
# thanks!

# %%
get_positive_integer_from_user()
# Out:
# Enter a positive integer: 7
# thanks!

# %% [markdown]
# ## Comprehensions

# %% [markdown]
# **IF**

# %%
a=15
if a > 10:
    s = "mayor que 10"
else:
    s = "menor que 10"

print(s)
# Out:
# mayor que 10

# %%
a = 5
s = "mayor que 10" if a > 10 else "menor que 10"
print(s)
# Out:
# menor que 10

# %% [markdown]
# **FOR**

# %%
b = [1,10, 20.5, "hola", 10.4, 12]

# %%
r = []
for i in b:
    r.append(int_times_two(i))
r
# Out:
# [2, 20, 40, 0, 20, 24]

# %%
r = [int_times_two(i) for i in b]
r
# Out:
# [2, 20, 40, 0, 20, 24]

# %% [markdown]
# **FOR / IF filter**

# %%
r = [int_times_two(i) for i in b if type(i)!=int or i > 10]
r
# Out:
# [40, 0, 20, 24]

# %% [markdown]
# **DICT**

# %%
r = {i: int_times_two(i) for i in b if type(i)!=int or i > 10}
r
# Out:
# {20.5: 40, 'hola': 0, 10.4: 20, 12: 24}

# %%
r['hola']
# Out:
# 0
